# %%
#import library
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# !pip install kneed
# Out:
# Requirement already satisfied: kneed in c:\users\fatur\anaconda3\lib\site-packages (0.8.1)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\fatur\anaconda3\lib\site-packages (from kneed) (1.21.5)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\fatur\anaconda3\lib\site-packages (from kneed) (1.7.3)

# %%
#lakukan import dataset
df_data = pd.read_csv("C://Users//fatur//Downloads//Property Dataset - Clustering - Data Rumah.csv")
df_data.head()
# Out:
#     Area Category       Nama Daerah  Luas Tanah (m2) Luas Bangunan (m2)  \
# 0             NaN               NaN              NaN                NaN
# 1  Below Standard  Setro Baru Utara             30.0              60.00
# 2        Standard          Kenjeran            170.0             170.00
# 3  Sangat Premium          Kenjeran            187.0             250.00
# 4         Premium          Kenjeran            350.0             600.00
#
#    Jumlah Kamar  Jumlah Kamar Mandi  Tingkat/Lantai   \
# 0           NaN                 NaN              NaN
# 1           2.0                 1.0              2.0
# 2           5.0                 4.0              2.0
# 3           5.0                 5.0              2.0
# 4           5.0                 5.0              2.0
#
#   Harga Penawaran (dari Owner) Terjual/Belum Arah Hadap Rumah  \
# 0                          NaN           NaN              NaN
# 1                    287799000         Belum              NaN
# 2                   2699999999         Belum          Selatan
# 3                   3100000000         Belum            Utara
# 4                   5000000000         Belum            Barat
#
#                   Posisi Rumah Lebar Jalan Depan Rumah (ROW)
# 0                          NaN                           NaN
# 1                     Standard                     < 1 Mobil
# 2  Cul De Sac/Ujung Gang Buntu                     1-2 Mobil
# 3                     Standard                     1-2 Mobil
# 4                     Standard                     1-2 Mobil

# %%
#menghapus row pertama yang NaN
df = df_data.tail(df_data.shape[0] -1)
df.head()
# Out:
#     Area Category       Nama Daerah  Luas Tanah (m2) Luas Bangunan (m2)  \
# 1  Below Standard  Setro Baru Utara             30.0              60.00
# 2        Standard          Kenjeran            170.0             170.00
# 3  Sangat Premium          Kenjeran            187.0             250.00
# 4         Premium          Kenjeran            350.0             600.00
# 5         Premium          Kenjeran            450.0             530.00
#
#    Jumlah Kamar  Jumlah Kamar Mandi  Tingkat/Lantai   \
# 1           2.0                 1.0              2.0
# 2           5.0                 4.0              2.0
# 3           5.0                 5.0              2.0
# 4           5.0                 5.0              2.0
# 5           5.0                 6.0              2.0
#
#   Harga Penawaran (dari Owner) Terjual/Belum Arah Hadap Rumah  \
# 1                    287799000         Belum              NaN
# 2                   2699999999         Belum          Selatan
# 3                   3100000000         Belum            Utara
# 4                   5000000000         Belum            Barat
# 5                  10800000000         Belum              NaN
#
#                   Posisi Rumah Lebar Jalan Depan Rumah (ROW)
# 1                     Standard                     < 1 Mobil
# 2  Cul De Sac/Ujung Gang Buntu                     1-2 Mobil
# 3                     Standard                     1-2 Mobil
# 4                     Standard                     1-2 Mobil
# 5                     Standard                     1-2 Mobil

# %%
#cek missing value
df.isnull().sum()
# Out:
# Area Category                      0
# Nama Daerah                        0
# Luas Tanah (m2)                    0
# Luas Bangunan (m2)                 0
# Jumlah Kamar                       0
# Jumlah Kamar Mandi                 1
# Tingkat/Lantai                     1
# Harga Penawaran (dari Owner)       0
# Terjual/Belum                      0
# Arah Hadap Rumah                  82
# Posisi Rumah                     115
# Lebar Jalan Depan Rumah (ROW)     41
# dtype: int64

# %%
#lakukan fill missing value
from random import choices
hadap_rumah = ["Timur", "Barat", "Selatan", "Utara"]
posisi_rumah = ["Timur", "Barat", "Selatan", "Utara"]
fill = choices(hadap_rumah, k=82)
fill_posisi = choices(posisi_rumah, k=115)

df['Jumlah Kamar Mandi'].replace([np.nan], df['Jumlah Kamar Mandi'].mode()[0], inplace = True)
df['Tingkat/Lantai '].replace([np.nan], df['Tingkat/Lantai '].mode()[0], inplace = True)
df['Lebar Jalan Depan Rumah (ROW)'].replace([np.nan], df['Lebar Jalan Depan Rumah (ROW)'].mode()[0], inplace = True)

for i in df['Arah Hadap Rumah'].isnull():
    df['Arah Hadap Rumah'].replace([np.nan], fill[i], inplace = True)
    
for i in df['Posisi Rumah'].isnull():
    df['Posisi Rumah'].replace([np.nan], fill_posisi[i], inplace = True)
# Out:
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1519517531.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jumlah Kamar Mandi'].replace([np.nan], df['Jumlah Kamar Mandi'].mode()[0], inplace = True)
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1519517531.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tingkat/Lantai '].replace([np.nan], df['Tingkat/Lantai '].mode()[0], inplace = True)
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1519517531.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Lebar Jalan Depan Rumah (ROW)'].replace([np.nan], df['Lebar Jalan Depan Rumah (ROW)'].mode()[0], inplace = True)
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1519517531.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Arah Hadap Rumah'].replace([np.nan], fill[i], inplace = True)
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1519517531.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Posisi Rumah'].replace([np.nan], fill_posisi[i], inplace = True)

# %%
#cek kembali missing value
df.isnull().sum()
# Out:
# Area Category                    0
# Nama Daerah                      0
# Luas Tanah (m2)                  0
# Luas Bangunan (m2)               0
# Jumlah Kamar                     0
# Jumlah Kamar Mandi               0
# Tingkat/Lantai                   0
# Harga Penawaran (dari Owner)     0
# Terjual/Belum                    0
# Arah Hadap Rumah                 0
# Posisi Rumah                     0
# Lebar Jalan Depan Rumah (ROW)    0
# dtype: int64

# %%
#lakukan label encoder
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
df['Area Category'] = lb.fit_transform(df['Area Category'])
df['Nama Daerah'] = lb.fit_transform(df['Nama Daerah'])
df['Luas Tanah (m2)'] = lb.fit_transform(df['Luas Tanah (m2)'])
df['Luas Bangunan (m2)'] = lb.fit_transform(df['Luas Bangunan (m2)'])
df['Jumlah Kamar'] = lb.fit_transform(df['Jumlah Kamar'])
df['Jumlah Kamar Mandi'] = lb.fit_transform(df['Jumlah Kamar Mandi'])
df['Tingkat/Lantai '] = lb.fit_transform(df['Tingkat/Lantai '])
df['Harga Penawaran (dari Owner)'] = lb.fit_transform(df['Harga Penawaran (dari Owner)'])
df['Terjual/Belum'] = lb.fit_transform(df['Terjual/Belum'])
df['Arah Hadap Rumah'] = lb.fit_transform(df['Arah Hadap Rumah'])
df['Posisi Rumah'] = lb.fit_transform(df['Posisi Rumah'])
df['Lebar Jalan Depan Rumah (ROW)'] = lb.fit_transform(df['Lebar Jalan Depan Rumah (ROW)'])
# Out:
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1139793478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Area Category'] = lb.fit_transform(df['Area Category'])
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1139793478.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Nama Daerah'] = lb.fit_transform(df['Nama Daerah'])
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1139793478.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Luas Tanah (m2)'] = lb.fit_transform(df['Luas Tanah (m2)'])
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1139793478.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Luas Bangunan (m2)'] = lb.fit_transform(df['Luas Bangunan (m2)'])
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1139793478.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jumlah Kamar'] = lb.fit_transform(df['Jumlah Kamar'])
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1139793478.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jumlah Kamar Mandi'] = lb.fit_transform(df['Jumlah Kamar Mandi'])
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1139793478.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tingkat/Lantai '] = lb.fit_transform(df['Tingkat/Lantai '])
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1139793478.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Harga Penawaran (dari Owner)'] = lb.fit_transform(df['Harga Penawaran (dari Owner)'])
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1139793478.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Terjual/Belum'] = lb.fit_transform(df['Terjual/Belum'])
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1139793478.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Arah Hadap Rumah'] = lb.fit_transform(df['Arah Hadap Rumah'])
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1139793478.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Posisi Rumah'] = lb.fit_transform(df['Posisi Rumah'])
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\1139793478.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Lebar Jalan Depan Rumah (ROW)'] = lb.fit_transform(df['Lebar Jalan Depan Rumah (ROW)'])

# %%
#
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_scale = sc.fit_transform(df.to_numpy())
df_scale = pd.DataFrame(df_scale, columns=['Area Category','Nama Daerah','Luas Tanah (m2)','Luas Bangunan (m2)','Jumlah Kamar','Jumlah Kamar Mandi','Tingkat/Lantai','Harga Penawaran (dari Owner)','Terjual/Belum','Arah Hadap Rumah','Posisi Rumah','Lebar Jalan Depan Rumah (ROW)'])
df_scale.head()
# Out:
#    Area Category  Nama Daerah  Luas Tanah (m2)  Luas Bangunan (m2)  \
# 0      -1.674585     1.044551        -1.684782            1.149415
# 1       1.007663    -0.370401         0.085221           -0.743591
# 2       0.113581    -0.370401         0.195846           -0.206071
# 3      -0.780502    -0.370401         1.025535            1.196156
# 4      -0.780502    -0.370401         1.357411            1.009192
#
#    Jumlah Kamar  Jumlah Kamar Mandi  Tingkat/Lantai  \
# 0     -1.416778           -1.486571        0.287019
# 1      0.458010            0.430981        0.287019
# 2      0.458010            1.070165        0.287019
# 3      0.458010            1.070165        0.287019
# 4      0.458010            1.709349        0.287019
#
#    Harga Penawaran (dari Owner)  Terjual/Belum  Arah Hadap Rumah  \
# 0                     -0.055303            0.0         -0.650889
# 1                     -0.162352            0.0         -0.650889
# 2                      0.051746            0.0          1.463639
# 3                      0.908140            0.0         -1.708153
# 4                     -1.639631            0.0         -0.650889
#
#    Posisi Rumah  Lebar Jalan Depan Rumah (ROW)
# 0     -0.826489                       0.218033
# 1     -2.209224                      -0.827844
# 2     -0.826489                      -0.827844
# 3     -0.826489                      -0.827844
# 4     -0.826489                      -0.827844

# %%
from sklearn.cluster import KMeans

sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(df_scale)
    sse.append(kmeans.inertia_)
# Out:
# C:\Users\fatur\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel('Number of Cluster')
plt.ylabel('SSE');

# %%
from kneed import KneeLocator
k = KneeLocator(range(1,11), sse, curve='convex', direction='decreasing')
print('Elbow/Knee: ', k.elbow)
# Out:
# Elbow/Knee:  3

# %%
kmeans = KMeans(init="random",n_clusters=4,max_iter=300,random_state=42)
pred = kmeans.fit_predict(df_scale)
pred
df['K Means'] = pred
# Out:
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\907867623.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['K Means'] = pred

# %%
df.groupby('K Means').agg(
area = ('Area Category', pd.Series.mode), daerah = ('Nama Daerah', pd.Series.mode), 
luas_tanah = ('Luas Tanah (m2)', pd.Series.mean), luas_bangunan = ('Luas Bangunan (m2)', pd.Series.mean),
jumlah_kamar = ('Jumlah Kamar', pd.Series.mean), jumlah_kamar_mandi = ('Jumlah Kamar Mandi', pd.Series.mean),
tingkat_lantai = ('Tingkat/Lantai ', pd.Series.mean), harga_penawaran = ('Harga Penawaran (dari Owner)', pd.Series.mean), 
terjual_belum = ('Terjual/Belum', pd.Series.mode), arah_hadapan_rumah = ('Arah Hadap Rumah', pd.Series.mode), 
posisi_rumah = ('Posisi Rumah', pd.Series.mode), lebar_jalan_depan_rumah = ('Lebar Jalan Depan Rumah (ROW)', pd.Series.mean), Count = ('K Means', 'count'))
# Out:
#          area    daerah  luas_tanah  luas_bangunan  jumlah_kamar  \
# K Means
# 0           3        11   24.226415     119.735849      1.396226
# 1           1  [11, 82]   91.300000      80.412500      4.300000
# 2           1        11   97.106061      81.030303      4.500000
# 3           3  [30, 73]   48.518519      27.777778      2.666667
#
#          jumlah_kamar_mandi  tingkat_lantai  harga_penawaran  terjual_belum  \
# K Means
# 0                  0.547170        1.018868        94.679245              0
# 1                  3.487500        2.075000        97.087500              0
# 2                  3.409091        1.939394        93.560606              0
# 3                  1.675926        1.638889        59.194444              0
#
#         arah_hadapan_rumah  posisi_rumah  lebar_jalan_depan_rumah  Count
# K Means
# 0                        1             2                 0.660377     53
# 1                        1             2                 0.012500     80
# 2                   [1, 3]             5                 2.000000     66
# 3                        1             2                 0.694444    108

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
plt.figure(figsize=(20,7))
linkage_data = linkage(df_scale, method='average', metric='euclidean',)
dendrogram(linkage_data)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering # this line of code imports AgglomerativeClustering model from sk-learn
Agg_hc = AgglomerativeClustering(n_clusters = 5, affinity = 'euclidean', linkage = 'single')
y_hc = Agg_hc.fit_predict(df_scale) # model fitting on the dataset
df['K Means'] = y_hc
# Out:
# C:\Users\fatur\AppData\Local\Temp\ipykernel_19344\689594878.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['K Means'] = y_hc

# %%
df.groupby('K Means').agg(
area = ('Area Category', pd.Series.mode), daerah = ('Nama Daerah', pd.Series.mode), 
luas_tanah = ('Luas Tanah (m2)', pd.Series.mean), luas_bangunan = ('Luas Bangunan (m2)', pd.Series.mean),
jumlah_kamar = ('Jumlah Kamar', pd.Series.mean), jumlah_kamar_mandi = ('Jumlah Kamar Mandi', pd.Series.mean),
tingkat_lantai = ('Tingkat/Lantai ', pd.Series.mean), harga_penawaran = ('Harga Penawaran (dari Owner)', pd.Series.mean), 
terjual_belum = ('Terjual/Belum', pd.Series.mode), arah_hadapan_rumah = ('Arah Hadap Rumah', pd.Series.mode), 
posisi_rumah = ('Posisi Rumah', pd.Series.mode), lebar_jalan_depan_rumah = ('Lebar Jalan Depan Rumah (ROW)', pd.Series.mean), Count = ('K Means', 'count'))
# Out:
#          area  daerah  luas_tanah  luas_bangunan  jumlah_kamar  \
# K Means
# 0           3      11   65.316832       68.59736      3.217822
# 1           2     122  130.000000      109.00000      6.000000
# 2           3      42   84.000000       84.00000      9.000000
# 3           2       1   99.000000      136.00000      7.000000
# 4           2      82  133.000000       13.00000      6.000000
#
#          jumlah_kamar_mandi  tingkat_lantai  harga_penawaran  terjual_belum  \
# K Means
# 0                  2.260726         1.69637        82.561056              0
# 1                  7.000000         2.00000        11.000000              0
# 2                  8.000000         2.00000        76.000000              0
# 3                  7.000000         5.00000       142.000000              0
# 4                  7.000000         2.00000       108.000000              0
#
#          arah_hadapan_rumah  posisi_rumah  lebar_jalan_depan_rumah  Count
# K Means
# 0                         1             2                 0.788779    303
# 1                         2             5                 2.000000      1
# 2                         1             2                 2.000000      1
# 3                         3             5                 0.000000      1
# 4                         1             5                 0.000000      1
